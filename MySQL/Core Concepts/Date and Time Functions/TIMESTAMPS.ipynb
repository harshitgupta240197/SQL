# %% [markdown]
# #### MySQL connection

# %%
# %load_ext sql
# %config SqlMagic.autopandas = True
# %config SqlMagic.feedback = False

import os
from dotenv import load_dotenv
from sqlalchemy import create_engine
from sqlalchemy.engine.url import URL

load_dotenv()

url = URL.create("mysql+pymysql",
                 username="root",
                 password=os.getenv('MYSQL_PW'),
                 host="localhost")
engine = create_engine(url)
# %sql engine

# %% [markdown]
# # TIMESTAMP()
# #### A TIMESTAMP takes smaller space in memory as compared to DATETIME

# %% [markdown]
# ### DATETIME vs TIMESTAMP
#
# | Description | DATETIME | TIMESTAMP |
# |---|---|---|
# | Format | YYYY-MM-DD HH:MM:SS | YYYY-MM-DD HH:MM:SS |
# | Range | January 1, 1000 to December 31, 9999 | January 1, 1970 to December 31, 2038 |
# | Storage Size | 8 bytes | 4 bytes (pre-2038) / 8 bytes (post-2038) |
# | Timezone | No timezone conversion | Converts to/from UTC based on server timezone |
# | Default Value | No automatic updates | Can auto-update with `DEFAULT CURRENT_TIMESTAMP` and `ON UPDATE CURRENT_TIMESTAMP` |

# %% [markdown]
# # When we use NOW() we are using a TIMESTAMP and not DATETIME

# %%
# %%sql
#
# USE dog_world;
#
# CREATE TABLE captions
#     (
#         text VARCHAR(200),
#         created_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP
#     );
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%sql
#
# INSERT INTO captions (text)
# VALUES
#     ('This is MySQL learning in peogress')
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%sql
#
# INSERT INTO captions (text)
# VALUES
#     ('Today we discussed Date and Time properties'),
#     ('We also learnt about TIMESTAMPS as well')
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%sql
#
# SELECT *
# FROM captions
# Out:
#                                           text          created_at
# 0           This is MySQL learning in peogress 2026-08-06 13:24:11
# 1  Today we discussed Date and Time properties 2026-08-06 13:25:20
# 2      We also learnt about TIMESTAMPS as well 2026-08-06 13:25:20

# %% [markdown]
# #### Adding a column to the table that can store UPDATED_AT values

# %%
# %%sql
#
# USE dog_world;
#
# ALTER TABLE captions
#     ADD COLUMN updated_at TIMESTAMP ON UPDATE CURRENT_TIMESTAMP
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%sql
#
# INSERT INTO captions (text)
# VALUES ('How was your day today ?')
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%sql
#
# SELECT *
# FROM captions
# Out:
#                                           text          created_at updated_at
# 0           This is MySQL learning in peogress 2026-08-06 13:24:11       None
# 1  Today we discussed Date and Time properties 2026-08-06 13:25:20       None
# 2      We also learnt about TIMESTAMPS as well 2026-08-06 13:25:20       None
# 3                     How was your day today ? 2026-08-06 13:42:23       None

# %%
# %%sql
#
# UPDATE captions SET text = 'How is Life going ?'
# WHERE text = 'How was your day today ?'
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%sql
#
# SELECT *
# FROM captions
# Out:
#                                           text          created_at  \
# 0           This is MySQL learning in peogress 2026-08-06 13:24:11
# 1  Today we discussed Date and Time properties 2026-08-06 13:25:20
# 2      We also learnt about TIMESTAMPS as well 2026-08-06 13:25:20
# 3                          How is Life going ? 2026-08-06 13:42:23
#
#            updated_at
# 0                 NaT
# 1                 NaT
# 2                 NaT
# 3 2026-08-06 13:42:31
