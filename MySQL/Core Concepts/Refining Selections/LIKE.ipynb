# %% [markdown]
# #### Connection to MySQL

# %%
# %load_ext sql
# %config SqlMagic.autopandas = True
# %config SqlMagic.feedback = False

import os
from dotenv import load_dotenv
from sqlalchemy import create_engine
from sqlalchemy.engine.url import URL

load_dotenv()

url = URL.create("mysql+pymysql",
                 username="root",
                 password=os.getenv('MYSQL_PW'),
                 host="localhost")
engine = create_engine(url)
# %sql engine

# %% [markdown]
# # LIKE
# ```sql
# SELECT
#     column1,
#     column2
# FROM table_name
# WHERE column1 LIKE '%search-term%'
# ```
# #### Here % is the wildcard

# %%
# %%sql
#
# USE book_shop;
#
# SELECT *
# FROM books
# WHERE author_fname LIKE '%Dave%'
# LIMIT 5;
# Out:
#    book_id                                      title author_fname  \
# 0        5           A Hologram for the King: A Novel         Dave
# 1        6                                 The Circle         Dave
# 2        9  A Heartbreaking Work of Staggering Genius         Dave
#
#   author_lname  released_year  stock_quantity  pages
# 0       Eggers           2012             154    352
# 1       Eggers           2013              26    504
# 2       Eggers           2001             104    437

# %% [markdown]
# # LIKE - UNDERSCORES(_)
# #### Underscore _ represents a character

# %% [markdown]
# #### We will use this LIKE _ to find the authors with first name as exactly 4 characters

# %%
# %%sql
#
# SELECT *
# FROM books
# WHERE author_fname LIKE '____'
# Out:
#    book_id                                      title author_fname  \
# 0        2                            Norse Mythology         Neil
# 1        3                              American Gods         Neil
# 2        5           A Hologram for the King: A Novel         Dave
# 3        6                                 The Circle         Dave
# 4        9  A Heartbreaking Work of Staggering Genius         Dave
# 5       10                                   Coraline         Neil
# 6       14                                Cannery Row         John
#
#   author_lname  released_year  stock_quantity  pages
# 0       Gaiman           2016              43    304
# 1       Gaiman           2001              12    465
# 2       Eggers           2012             154    352
# 3       Eggers           2013              26    504
# 4       Eggers           2001             104    437
# 5       Gaiman           2003             100    208
# 6    Steinbeck           1945              95    181

# %%
# %%sql
#
# SELECT *
# FROM books
# WHERE author_fname LIKE '_a__'
# Out:
#    book_id                                      title author_fname  \
# 0        5           A Hologram for the King: A Novel         Dave
# 1        6                                 The Circle         Dave
# 2        9  A Heartbreaking Work of Staggering Genius         Dave
#
#   author_lname  released_year  stock_quantity  pages
# 0       Eggers           2012             154    352
# 1       Eggers           2013              26    504
# 2       Eggers           2001             104    437

# %% [markdown]
# # Escaping Wildcards

# %% [markdown]
# #### If we want to search for the book title 10% happier which already has a % in the title then we will have to use the escape character

# %%
# %%sql
#
# SELECT *
# FROM books
# WHERE title LIKE '%\%%'
# Out:
#    book_id        title author_fname author_lname  released_year  \
# 0       17  10% Happier          Dan       Harris           2014
#
#    stock_quantity  pages
# 0              29    256

# %% [markdown]
# #### In case the name has a _

# %%
# %%sql
#
# SELECT *
# FROM books
# WHERE title LIKE '%\_%'
# Out:
#    book_id      title author_fname author_lname  released_year  \
# 0       18  fake_book       Freida       Harris           2001
#
#    stock_quantity  pages
# 0             287    428
