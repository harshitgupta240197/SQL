# %% [markdown]
# #### Connection to MySQL

# %%
# %load_ext sql
# %config SqlMagic.autopandas = True
# %config SqlMagic.feedback = False

import os
from dotenv import load_dotenv
from sqlalchemy import create_engine
from sqlalchemy.engine.url import URL

load_dotenv()

url = URL.create("mysql+pymysql",
                 username="root",
                 password=os.getenv('MYSQL_PW'),
                 host="localhost")
engine = create_engine(url)
# %sql engine

# %% [markdown]
# # Grouping By Multiple Columns

# %%
# %%sql
#
# USE book_shop;
#
# SELECT
#     author_lname,
#     author_fname,
#     COUNT(*)
# FROM books
# GROUP BY author_lname, author_fname
# Out:
#       author_lname author_fname  COUNT(*)
# 0           Lahiri       Jhumpa         2
# 1           Gaiman         Neil         3
# 2           Eggers         Dave         3
# 3           Chabon      Michael         1
# 4            Smith        Patti         1
# 5           Carver      Raymond         2
# 6          DeLillo          Don         1
# 7        Steinbeck         John         1
# 8   Foster Wallace        David         2
# 9           Harris          Dan         1
# 10          Harris       Freida         1
# 11        Saunders       George         1
