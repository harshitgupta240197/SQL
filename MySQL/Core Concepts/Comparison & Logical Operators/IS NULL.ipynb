# %% [markdown]
# #### Connection to MySQL

# %%
# %load_ext sql
# %config SqlMagic.autopandas = True
# %config SqlMagic.feedback = False

import os
from dotenv import load_dotenv
from sqlalchemy import create_engine
from sqlalchemy.engine.url import URL

load_dotenv()

url = URL.create("mysql+pymysql",
                 username="root",
                 password=os.getenv('MYSQL_PW'),
                 host="localhost")
engine = create_engine(url)
# %sql engine

# %% [markdown]
# # IS NULL

# %%
# %%sql
#
# USE book_shop;
#
# SELECT *
# FROM books
# LIMIT 2;
# Out:
#    book_id            title author_fname author_lname  released_year  \
# 0        1     The Namesake       Jhumpa       Lahiri           2003
# 1        2  Norse Mythology         Neil       Gaiman           2016
#
#    stock_quantity  pages
# 0              32    291
# 1              43    304

# %%
# %%sql
#
# INSERT INTO books (title, author_fname, author_lname)
# VALUES('A good day to live!', 'Fischer', 'Raymond')
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### Using IS NULL we are able to locate the released_year with NULL value

# %%
# %%sql
#
# SELECT *
# FROM books
# WHERE released_year IS NULL
# Out:
#    book_id                title author_fname author_lname released_year  \
# 0       20  A good day to live!      Fischer      Raymond          None
#
#   stock_quantity pages
# 0           None  None

# %% [markdown]
# # IS NOT NULL

# %%
# %%sql
#
# SELECT *
# FROM books
# WHERE released_year IS NOT NULL
# Out:
#     book_id                                              title author_fname  \
# 0         1                                       The Namesake       Jhumpa
# 1         2                                    Norse Mythology         Neil
# 2         3                                      American Gods         Neil
# 3         4                            Interpreter of Maladies       Jhumpa
# 4         5                   A Hologram for the King: A Novel         Dave
# 5         6                                         The Circle         Dave
# 6         7          The Amazing Adventures of Kavalier & Clay      Michael
# 7         8                                          Just Kids        Patti
# 8         9          A Heartbreaking Work of Staggering Genius         Dave
# 9        10                                           Coraline         Neil
# 10       11  What We Talk About When We Talk About Love: St...      Raymond
# ...

# %%
# %%sql
#
# DELETE FROM books
# WHERE released_year IS NULL
# Out:
# Empty DataFrame
# Columns: []
# Index: []
